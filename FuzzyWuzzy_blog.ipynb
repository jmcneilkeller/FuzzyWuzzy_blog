# %%
import pandas as pd
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process
import csv

# %%
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 300)
from tqdm import tqdm_notebook as tqdm

# %%
source = pd.read_csv('visa_clean.csv',index_col=0)
sample = int(0.15*len(df))
df = source.sample(sample)
df.info()
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (1,2,10,11,12,13,17,18,21,22,23,24,25,26,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56154 entries, 80961 to 372944
# Data columns (total 31 columns):
# application_type                 20082 non-null object
# case_received_date               36072 non-null object
# case_status                      56154 non-null object
# class_of_admission               52751 non-null object
# decision_date                    56154 non-null object
# employer_city                    56151 non-null object
# employer_name                    56152 non-null object
# employer_num_employees           36062 non-null float64
# employer_state                   56145 non-null object
# foreign_worker_info_city         36068 non-null object
# ...

# %%
with open('f500.csv', 'r') as f:
    reader = csv.reader(f)
    f500_list = list(reader)

# %%
f500_list
# Out:
# [['f500_name'],
#  ['CIT Group Inc.'],
#  ['General Electric'],
#  ['Parker-Hannifin'],
#  ['KeyCorp'],
#  ['AmTrust Financial Services, Inc.'],
#  ['Dover'],
#  ['Hanesbrands'],
#  ['Casey’s General Stores, Inc.'],
#  ['Fluor'],
#  ['Dollar General Corporation'],
#  ['Avon Products, Inc.'],
#  ['Essendant'],
#  ['Ralcorp Holdings, Inc.'],
#  ['Brink’s'],
#  ['CDW'],
#  ['TrueBlue'],
#  ['Jones Lang LaSalle Incorporated'],
#  ['Caesars Entertainment Corporation'],
#  ['The Timken Company'],
#  ['Google'],
#  ['Honeywell International Inc.'],
#  ['Vishay Intertechnology, Inc.'],
#  ['Anadarko Petroleum Corporation'],
#  ['Rent-A-Center'],
#  ['Buckeye Partners, L.P.'],
#  ['Gardner Denver, Inc.'],
#  ['Wisconsin Energy Corporation'],
#  ['Kindred Healthcare, Inc.'],
#  ['Alpha Natural Resources, Inc.'],
#  ['Curtiss-Wright Corporation'],
#  ['TreeHouse Foods, Inc.'],
#  ['Quintiles Transnational Holdings Inc.'],
#  ['Tenneco'],
#  ['Trimble'],
#  ['Oshkosh Corporation'],
# ...

# %%
f500_1 = []
for company in tqdm(df['employer_name']):
    if type(company) != str: # Checking base case. 
        pass
    else:
        match = process.extractOne(company, f500_list) #Returns tuple of best match and percent fit.
        f500_1.append(company)
        f500_1.append(match)

# %%
import pprint

# %%
f500_1[:201]
# Out:
# ['XL GLOBAL SERVICES',
#  (['AmTrust Financial Services, Inc.'], 86),
#  'AIMIC INC',
#  (['AmTrust Financial Services, Inc.'], 86),
#  'SPLN INTERNATIONAL LLC',
#  (['Harman International Industries, Incorporated'], 86),
#  'CUMMINS INC.',
#  (['Cummins Inc.'], 100),
#  "BURT'S BEES, INC.",
#  (['AmTrust Financial Services, Inc.'], 86),
#  'ATLAS WIRELESS AND TELECOMMUNICATIONS, INC.',
#  (['CIT Group Inc.'], 86),
#  'YER USA, INC.',
#  (['AmTrust Financial Services, Inc.'], 86),
#  'RUBRIK, INC.',
#  (['AmTrust Financial Services, Inc.'], 86),
#  'PIONEER HI-BRED INTERNATIONAL, INC.',
#  (['CIT Group Inc.'], 86),
#  'MEDIANA TECHNOLOGIES CORPORATION',
#  (['Oshkosh Corporation'], 86),
#  'MAYO CLINIC',
#  (['Olin'], 68),
#  'PINTEREST, INC.',
#  (['AmTrust Financial Services, Inc.'], 86),
#  'EPIC',
#  (['PepsiCo'], 73),
#  'SOMERVILLE COMMUNITY BAPTIST CHURCH, INC.',
#  (['CIT Group Inc.'], 86),
#  'Z&A INFOTEK CORPORATION',
#  (['Rent-A-Center'], 86),
#  'APIIS FINANCIAL, INC.',
# ...

# %%
f500_1 = []
for company in tqdm(df['employer_name']):
    if type(company) != str: # Checking base case. 
        pass
    else:
        match = process.extractOne(company, f500_list, scorer=) #Returns tuple of best match and percent fit.
        f500_1.append(company)
        f500_1.append(match)
